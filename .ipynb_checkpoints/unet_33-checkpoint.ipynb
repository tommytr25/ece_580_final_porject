# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn

# Set matplotlib to display in notebook
# %matplotlib inline

# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding='same'),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding='same'),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.double_conv(x)

class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()
        # Encoder
        self.conv1 = DoubleConv(1, 32)
        self.conv2 = DoubleConv(32, 64)
        self.conv3 = DoubleConv(64, 128)
        
        # Decoder
        self.up_conv2 = DoubleConv(192, 64)  # 128 + 64 channels
        self.up_conv1 = DoubleConv(96, 32)   # 64 + 32 channels
        
        # Final convolution
        self.final_conv = nn.Conv2d(32, 3, kernel_size=1)
        
        # Pooling and upsampling
        self.pool = nn.MaxPool2d(2)
        self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        
    def forward(self, x):
        # Encoder
        conv1 = self.conv1(x)           # 32x32 -> 32x32
        x = self.pool(conv1)            # 32x32 -> 16x16
        
        conv2 = self.conv2(x)           # 16x16 -> 16x16
        x = self.pool(conv2)            # 16x16 -> 8x8
        
        # Bridge
        x = self.conv3(x)               # 8x8 -> 8x8
        
        # Decoder
        x = self.up(x)                  # 8x8 -> 16x16
        x = torch.cat([x, conv2], dim=1)
        x = self.up_conv2(x)            # 16x16 -> 16x16
        
        x = self.up(x)                  # 16x16 -> 32x32
        x = torch.cat([x, conv1], dim=1)
        x = self.up_conv1(x)            # 32x32 -> 32x32
        
        # Final convolution
        x = self.final_conv(x)          # 32x32 -> 32x32
        return x

# Initialize model
model = UNet().to(device)
print("Model initialized")
# Out:
# Model initialized

# %%
class DemosaicingDataset(Dataset):
    def __init__(self, root_dir, split_file, patch_size=32, stride=32, transform=None):
        """Initialize Demosaicing dataset"""
        self.root_dir = root_dir
        self.groundtruth_dir = os.path.join(root_dir, 'groundtruth')
        self.input_dir = os.path.join(root_dir, 'input')
        self.patch_size = patch_size
        self.stride = stride
        self.transform = transform
        
        # Read image list from split file
        with open(split_file, 'r') as f:
            self.image_files = [line.strip() + '.png' for line in f.readlines()]
            
        print(f"Found {len(self.image_files)} images in {os.path.basename(split_file)}")
        
        # Pre-compute patches
        self.patches = self._prepare_patches()
        
    def _prepare_patches(self):
        """Prepare patches from all images"""
        patches = []
        
        for i, img_file in enumerate(self.image_files):
            print(f"Processing image {i+1}/{len(self.image_files)}", end='\r')
            
            # Load ground truth image
            gt_path = os.path.join(self.groundtruth_dir, img_file)
            gt_img = cv2.imread(gt_path)
            gt_img = cv2.cvtColor(gt_img, cv2.COLOR_BGR2RGB)
            
            # Load input image (raw Bayer)
            input_path = os.path.join(self.input_dir, img_file)
            input_img = cv2.imread(input_path, cv2.IMREAD_UNCHANGED)
            
            # Normalize input to [0, 1]
            input_img = input_img.astype(np.float32) / 65535.0
            gt_img = gt_img.astype(np.float32) / 255.0
            
            # Extract patches
            h, w = input_img.shape
            for i in range(0, h - self.patch_size + 1, self.stride):
                for j in range(0, w - self.patch_size + 1, self.stride):
                    input_patch = input_img[i:i+self.patch_size, j:j+self.patch_size]
                    gt_patch = gt_img[i:i+self.patch_size, j:j+self.patch_size]
                    
                    # Skip patches with low variance
                    if input_patch.std() > 0.01:
                        patches.append({
                            'input': input_patch,
                            'target': gt_patch,
                            'image_file': img_file,
                            'position': (i, j)
                        })
        
        print(f"\nExtracted {len(patches)} valid patches")
        return patches
    
    def __len__(self):
        return len(self.patches)
    
    def __getitem__(self, idx):
        patch = self.patches[idx]
        
        # Convert to torch tensors
        input_tensor = torch.from_numpy(patch['input']).float().unsqueeze(0)
        target_tensor = torch.from_numpy(patch['target']).float().permute(2, 0, 1)
        
        if self.transform:
            input_tensor = self.transform(input_tensor)
            target_tensor = self.transform(target_tensor)
            
        return {
            'input': input_tensor,
            'target': target_tensor,
            'image_file': patch['image_file'],
            'position': patch['position']
        }

# %%
def prepare_demosaicing_datasets(dataset_path, batch_size=32, num_workers=4):
    """Prepare training, validation and test datasets"""
    split_files = {
        'train': os.path.join(dataset_path, 'train.txt'),
        'val': os.path.join(dataset_path, 'validation.txt'),
        'test': os.path.join(dataset_path, 'test.txt')
    }
    
    datasets = {}
    dataloaders = {}
    
    for split_name, split_file in split_files.items():
        if os.path.exists(split_file):
            print(f"\nPreparing {split_name} dataset...")
            
            datasets[f'{split_name}_dataset'] = DemosaicingDataset(
                root_dir=dataset_path,
                split_file=split_file,
                patch_size=32,
                stride=32
            )
            
            dataloaders[f'{split_name}_loader'] = DataLoader(
                datasets[f'{split_name}_dataset'],
                batch_size=batch_size,
                shuffle=(split_name == 'train'),
                num_workers=num_workers,
                pin_memory=True
            )
        else:
            print(f"Warning: {split_file} not found. Skipping {split_name} split.")
    
    return {**datasets, **dataloaders}

# Prepare datasets
dataset_path = 'dataset/MSR-Demosaicing/MSR-Demosaicing/Dataset_LINEAR_without_noise/bayer_panasonic'
data = prepare_demosaicing_datasets(dataset_path=dataset_path, batch_size=32, num_workers=4)

# Print statistics
print("\nDataset Statistics:")
print("-" * 50)
for split in ['train', 'val', 'test']:
    if f'{split}_dataset' in data:
        print(f"{split.capitalize()} samples: {len(data[f'{split}_dataset'])}")
# Out:
# Preparing train dataset...
# Found 200 images in train.txt
# Processing image 200/200
# Extracted 4655 valid patches
#
# Preparing val dataset...
# Found 100 images in validation.txt
# Processing image 100/100
# Extracted 2369 valid patches
#
# Preparing test dataset...
# Found 200 images in test.txt
# Processing image 200/200
# Extracted 4626 valid patches
#
# Dataset Statistics:
# --------------------------------------------------
# Train samples: 4655
# Val samples: 2369
# Test samples: 4626

# %%
def train_epoch(model, train_loader, criterion, optimizer, device):
    """Train for one epoch"""
    model.train()
    running_loss = 0.0
    
    for i, batch in enumerate(train_loader):
        inputs = batch['input'].to(device)
        targets = batch['target'].to(device)
        
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * inputs.size(0)
        
        if (i + 1) % 10 == 0:
            print(f'Batch [{i+1}/{len(train_loader)}], Loss: {loss.item():.6f}', end='\r')
    
    return running_loss / len(train_loader.dataset)

def validate(model, val_loader, criterion, device):
    """Validate the model"""
    model.eval()
    running_loss = 0.0
    
    with torch.no_grad():
        for i, batch in enumerate(val_loader):
            inputs = batch['input'].to(device)
            targets = batch['target'].to(device)
            
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            
            running_loss += loss.item() * inputs.size(0)
            
            if (i + 1) % 10 == 0:
                print(f'Val Batch [{i+1}/{len(val_loader)}], Loss: {loss.item():.6f}', end='\r')
    
    return running_loss / len(val_loader.dataset)

# %%
# Training setup
criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.5)

# Training parameters
n_epochs = 150
best_val_loss = float('inf')
train_losses = []
val_losses = []

# Training loop
print("Starting training...")
for epoch in range(n_epochs):
    print(f'\nEpoch [{epoch+1}/{n_epochs}]')
    
    # Train
    train_loss = train_epoch(model, data['train_loader'], criterion, optimizer, device)
    train_losses.append(train_loss)
    
    # Validate
    val_loss = validate(model, data['val_loader'], criterion, device)
    val_losses.append(val_loss)
    
    # Scheduler step
    scheduler.step(val_loss)
    
    # Save best model
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'train_loss': train_loss,
            'val_loss': val_loss,
        }, 'best_unet_model.pth')
    
    # Print epoch results
    print(f'\nEpoch [{epoch+1}/{n_epochs}]')
    print(f'Train Loss: {train_loss:.6f}')
    print(f'Val Loss: {val_loss:.6f}')
    print(f'Learning Rate: {optimizer.param_groups[0]["lr"]:.6f}')

# Plot training results
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Losses')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Starting training...
#
# Epoch [1/150]
# Val Batch [70/75], Loss: 0.001131
# Epoch [1/150]
# Train Loss: 0.007359
# Val Loss: 0.002786
# Learning Rate: 0.001000
#
# Epoch [2/150]
# Val Batch [70/75], Loss: 0.000833
# Epoch [2/150]
# Train Loss: 0.002017
# Val Loss: 0.002467
# Learning Rate: 0.001000
#
# Epoch [3/150]
# Val Batch [70/75], Loss: 0.000894
# Epoch [3/150]
# Train Loss: 0.001803
# Val Loss: 0.002903
# Learning Rate: 0.001000
#
# Epoch [4/150]
# Val Batch [70/75], Loss: 0.000556
# Epoch [4/150]
# Train Loss: 0.001666
# Val Loss: 0.001782
# Learning Rate: 0.001000
#
# Epoch [5/150]
# Val Batch [70/75], Loss: 0.000515
# Epoch [5/150]
# Train Loss: 0.001390
# Val Loss: 0.001486
# Learning Rate: 0.001000
#
# Epoch [6/150]
# Val Batch [70/75], Loss: 0.000381
# Epoch [6/150]
# Train Loss: 0.001292
# Val Loss: 0.001397
# Learning Rate: 0.001000
#
# Epoch [7/150]
# Val Batch [70/75], Loss: 0.000521
# Epoch [7/150]
# Train Loss: 0.001337
# Val Loss: 0.001472
# Learning Rate: 0.001000
#
# Epoch [8/150]
# Val Batch [70/75], Loss: 0.000351
# Epoch [8/150]
# Train Loss: 0.001213
# Val Loss: 0.001221
# Learning Rate: 0.001000
#
# Epoch [9/150]
# Val Batch [70/75], Loss: 0.000278
# Epoch [9/150]
# Train Loss: 0.001010
# Val Loss: 0.000846
# Learning Rate: 0.001000
#
# Epoch [10/150]
# Val Batch [70/75], Loss: 0.000232
# Epoch [10/150]
# Train Loss: 0.000655
# Val Loss: 0.000632
# Learning Rate: 0.001000
#
# Epoch [11/150]
# Val Batch [70/75], Loss: 0.000181
# Epoch [11/150]
# Train Loss: 0.000523
# Val Loss: 0.000488
# Learning Rate: 0.001000
#
# Epoch [12/150]
# Val Batch [70/75], Loss: 0.000149
# Epoch [12/150]
# Train Loss: 0.000448
# Val Loss: 0.000473
# Learning Rate: 0.001000
#
# Epoch [13/150]
# Val Batch [70/75], Loss: 0.000136
# Epoch [13/150]
# Train Loss: 0.000436
# Val Loss: 0.000407
# Learning Rate: 0.001000
#
# Epoch [14/150]
# Val Batch [70/75], Loss: 0.000148
# Epoch [14/150]
# Train Loss: 0.000445
# Val Loss: 0.000472
# Learning Rate: 0.001000
#
# Epoch [15/150]
# Val Batch [70/75], Loss: 0.000128
# Epoch [15/150]
# Train Loss: 0.000372
# Val Loss: 0.000391
# Learning Rate: 0.001000
#
# Epoch [16/150]
# Val Batch [70/75], Loss: 0.000101
# Epoch [16/150]
# Train Loss: 0.000376
# Val Loss: 0.000380
# Learning Rate: 0.001000
#
# Epoch [17/150]
# Val Batch [70/75], Loss: 0.000104
# Epoch [17/150]
# Train Loss: 0.000360
# Val Loss: 0.000374
# Learning Rate: 0.001000
#
# Epoch [18/150]
# Val Batch [70/75], Loss: 0.000111
# Epoch [18/150]
# Train Loss: 0.000337
# Val Loss: 0.000375
# Learning Rate: 0.001000
#
# Epoch [19/150]
# Val Batch [70/75], Loss: 0.000108
# Epoch [19/150]
# Train Loss: 0.000322
# Val Loss: 0.000370
# Learning Rate: 0.001000
#
# Epoch [20/150]
# Val Batch [70/75], Loss: 0.000100
# Epoch [20/150]
# Train Loss: 0.000408
# Val Loss: 0.000349
# Learning Rate: 0.001000
#
# Epoch [21/150]
# Val Batch [70/75], Loss: 0.000094
# Epoch [21/150]
# Train Loss: 0.000314
# Val Loss: 0.000342
# Learning Rate: 0.001000
#
# Epoch [22/150]
# Val Batch [70/75], Loss: 0.000095
# Epoch [22/150]
# Train Loss: 0.000297
# Val Loss: 0.000341
# Learning Rate: 0.001000
#
# Epoch [23/150]
# Val Batch [70/75], Loss: 0.000090
# Epoch [23/150]
# Train Loss: 0.000288
# Val Loss: 0.000324
# Learning Rate: 0.001000
#
# Epoch [24/150]
# Val Batch [70/75], Loss: 0.000088
# Epoch [24/150]
# Train Loss: 0.000284
# Val Loss: 0.000323
# Learning Rate: 0.001000
#
# Epoch [25/150]
# Val Batch [70/75], Loss: 0.000097
# Epoch [25/150]
# Train Loss: 0.000309
# Val Loss: 0.000343
# Learning Rate: 0.001000
#
# Epoch [26/150]
# Val Batch [70/75], Loss: 0.000086
# Epoch [26/150]
# Train Loss: 0.000279
# Val Loss: 0.000329
# Learning Rate: 0.001000
#
# Epoch [27/150]
# Val Batch [70/75], Loss: 0.000102
# Epoch [27/150]
# Train Loss: 0.000323
# Val Loss: 0.000368
# Learning Rate: 0.001000
#
# Epoch [28/150]
# Val Batch [70/75], Loss: 0.000082
# Epoch [28/150]
# Train Loss: 0.000267
# Val Loss: 0.000309
# Learning Rate: 0.001000
#
# Epoch [29/150]
# Val Batch [70/75], Loss: 0.000102
# Epoch [29/150]
# Train Loss: 0.000262
# Val Loss: 0.000313
# Learning Rate: 0.001000
#
# Epoch [30/150]
# Val Batch [70/75], Loss: 0.000139
# Epoch [30/150]
# Train Loss: 0.000405
# Val Loss: 0.000419
# Learning Rate: 0.001000
#
# Epoch [31/150]
# Val Batch [70/75], Loss: 0.000108
# Epoch [31/150]
# Train Loss: 0.000304
# Val Loss: 0.000347
# Learning Rate: 0.001000
#
# Epoch [32/150]
# Val Batch [70/75], Loss: 0.000084
# Epoch [32/150]
# Train Loss: 0.000339
# Val Loss: 0.000323
# Learning Rate: 0.001000
#
# Epoch [33/150]
# Val Batch [70/75], Loss: 0.000084
# Epoch [33/150]
# Train Loss: 0.000267
# Val Loss: 0.000301
# Learning Rate: 0.001000
#
# Epoch [34/150]
# Val Batch [70/75], Loss: 0.000091
# Epoch [34/150]
# Train Loss: 0.000258
# Val Loss: 0.000337
# Learning Rate: 0.001000
#
# Epoch [35/150]
# Val Batch [70/75], Loss: 0.000086
# Epoch [35/150]
# Train Loss: 0.000249
# Val Loss: 0.000317
# Learning Rate: 0.001000
#
# Epoch [36/150]
# Val Batch [70/75], Loss: 0.000114
# Epoch [36/150]
# Train Loss: 0.000238
# Val Loss: 0.000340
# Learning Rate: 0.001000
#
# Epoch [37/150]
# Val Batch [70/75], Loss: 0.000097
# Epoch [37/150]
# Train Loss: 0.000256
# Val Loss: 0.000369
# Learning Rate: 0.001000
#
# Epoch [38/150]
# Val Batch [70/75], Loss: 0.000085
# Epoch [38/150]
# Train Loss: 0.000276
# Val Loss: 0.000308
# Learning Rate: 0.001000
#
# Epoch [39/150]
# Val Batch [70/75], Loss: 0.000073
# Epoch [39/150]
# Train Loss: 0.000242
# Val Loss: 0.000288
# Learning Rate: 0.001000
#
# Epoch [40/150]
# Val Batch [70/75], Loss: 0.000082
# Epoch [40/150]
# Train Loss: 0.000250
# Val Loss: 0.000309
# Learning Rate: 0.001000
#
# Epoch [41/150]
# Val Batch [70/75], Loss: 0.000075
# Epoch [41/150]
# Train Loss: 0.000225
# Val Loss: 0.000297
# Learning Rate: 0.001000
#
# Epoch [42/150]
# Val Batch [70/75], Loss: 0.000105
# Epoch [42/150]
# Train Loss: 0.000227
# Val Loss: 0.000338
# Learning Rate: 0.001000
#
# Epoch [43/150]
# Val Batch [70/75], Loss: 0.000082
# Epoch [43/150]
# Train Loss: 0.000266
# Val Loss: 0.000320
# Learning Rate: 0.001000
#
# Epoch [44/150]
# Val Batch [70/75], Loss: 0.000070
# Epoch [44/150]
# Train Loss: 0.000218
# Val Loss: 0.000284
# Learning Rate: 0.001000
#
# Epoch [45/150]
# Val Batch [70/75], Loss: 0.000068
# Epoch [45/150]
# Train Loss: 0.000209
# Val Loss: 0.000280
# Learning Rate: 0.001000
#
# Epoch [46/150]
# Val Batch [70/75], Loss: 0.000065
# Epoch [46/150]
# Train Loss: 0.000208
# Val Loss: 0.000275
# Learning Rate: 0.001000
#
# Epoch [47/150]
# Val Batch [70/75], Loss: 0.000078
# Epoch [47/150]
# Train Loss: 0.000221
# Val Loss: 0.000319
# Learning Rate: 0.001000
#
# Epoch [48/150]
# Val Batch [70/75], Loss: 0.000085
# Epoch [48/150]
# Train Loss: 0.000234
# Val Loss: 0.000318
# Learning Rate: 0.001000
#
# Epoch [49/150]
# Val Batch [70/75], Loss: 0.000072
# Epoch [49/150]
# Train Loss: 0.000200
# Val Loss: 0.000298
# Learning Rate: 0.001000
#
# Epoch [50/150]
# Val Batch [70/75], Loss: 0.000072
# Epoch [50/150]
# Train Loss: 0.000197
# Val Loss: 0.000284
# Learning Rate: 0.001000
#
# Epoch [51/150]
# Val Batch [70/75], Loss: 0.000067
# Epoch [51/150]
# Train Loss: 0.000197
# Val Loss: 0.000286
# Learning Rate: 0.001000
#
# Epoch [52/150]
# Val Batch [70/75], Loss: 0.000085
# Epoch [52/150]
# Train Loss: 0.000209
# Val Loss: 0.000296
# Learning Rate: 0.000500
#
# Epoch [53/150]
# Val Batch [70/75], Loss: 0.000060
# Epoch [53/150]
# Train Loss: 0.000181
# Val Loss: 0.000261
# Learning Rate: 0.000500
#
# Epoch [54/150]
# Val Batch [70/75], Loss: 0.000060
# Epoch [54/150]
# Train Loss: 0.000175
# Val Loss: 0.000262
# Learning Rate: 0.000500
#
# Epoch [55/150]
# Val Batch [70/75], Loss: 0.000061
# Epoch [55/150]
# Train Loss: 0.000172
# Val Loss: 0.000263
# Learning Rate: 0.000500
#
# Epoch [56/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [56/150]
# Train Loss: 0.000171
# Val Loss: 0.000262
# Learning Rate: 0.000500
#
# Epoch [57/150]
# Val Batch [70/75], Loss: 0.000060
# Epoch [57/150]
# Train Loss: 0.000169
# Val Loss: 0.000262
# Learning Rate: 0.000500
#
# Epoch [58/150]
# Val Batch [70/75], Loss: 0.000060
# Epoch [58/150]
# Train Loss: 0.000168
# Val Loss: 0.000266
# Learning Rate: 0.000500
#
# Epoch [59/150]
# Val Batch [70/75], Loss: 0.000062
# Epoch [59/150]
# Train Loss: 0.000167
# Val Loss: 0.000268
# Learning Rate: 0.000250
#
# Epoch [60/150]
# Val Batch [70/75], Loss: 0.000061
# Epoch [60/150]
# Train Loss: 0.000161
# Val Loss: 0.000260
# Learning Rate: 0.000250
#
# Epoch [61/150]
# Val Batch [70/75], Loss: 0.000060
# Epoch [61/150]
# Train Loss: 0.000159
# Val Loss: 0.000258
# Learning Rate: 0.000250
#
# Epoch [62/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [62/150]
# Train Loss: 0.000157
# Val Loss: 0.000259
# Learning Rate: 0.000250
#
# Epoch [63/150]
# Val Batch [70/75], Loss: 0.000060
# Epoch [63/150]
# Train Loss: 0.000156
# Val Loss: 0.000262
# Learning Rate: 0.000250
#
# Epoch [64/150]
# Val Batch [70/75], Loss: 0.000060
# Epoch [64/150]
# Train Loss: 0.000156
# Val Loss: 0.000258
# Learning Rate: 0.000250
#
# Epoch [65/150]
# Val Batch [70/75], Loss: 0.000060
# Epoch [65/150]
# Train Loss: 0.000155
# Val Loss: 0.000260
# Learning Rate: 0.000250
#
# Epoch [66/150]
# Val Batch [70/75], Loss: 0.000060
# Epoch [66/150]
# Train Loss: 0.000154
# Val Loss: 0.000261
# Learning Rate: 0.000250
#
# Epoch [67/150]
# Val Batch [70/75], Loss: 0.000061
# Epoch [67/150]
# Train Loss: 0.000153
# Val Loss: 0.000262
# Learning Rate: 0.000125
#
# Epoch [68/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [68/150]
# Train Loss: 0.000150
# Val Loss: 0.000259
# Learning Rate: 0.000125
#
# Epoch [69/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [69/150]
# Train Loss: 0.000149
# Val Loss: 0.000259
# Learning Rate: 0.000125
#
# Epoch [70/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [70/150]
# Train Loss: 0.000149
# Val Loss: 0.000260
# Learning Rate: 0.000125
#
# Epoch [71/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [71/150]
# Train Loss: 0.000148
# Val Loss: 0.000260
# Learning Rate: 0.000125
#
# Epoch [72/150]
# Val Batch [70/75], Loss: 0.000060
# Epoch [72/150]
# Train Loss: 0.000147
# Val Loss: 0.000261
# Learning Rate: 0.000125
#
# Epoch [73/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [73/150]
# Train Loss: 0.000147
# Val Loss: 0.000260
# Learning Rate: 0.000063
#
# Epoch [74/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [74/150]
# Train Loss: 0.000146
# Val Loss: 0.000259
# Learning Rate: 0.000063
#
# Epoch [75/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [75/150]
# Train Loss: 0.000145
# Val Loss: 0.000259
# Learning Rate: 0.000063
#
# Epoch [76/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [76/150]
# Train Loss: 0.000145
# Val Loss: 0.000259
# Learning Rate: 0.000063
#
# Epoch [77/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [77/150]
# Train Loss: 0.000144
# Val Loss: 0.000260
# Learning Rate: 0.000063
#
# Epoch [78/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [78/150]
# Train Loss: 0.000144
# Val Loss: 0.000260
# Learning Rate: 0.000063
#
# Epoch [79/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [79/150]
# Train Loss: 0.000144
# Val Loss: 0.000260
# Learning Rate: 0.000031
#
# Epoch [80/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [80/150]
# Train Loss: 0.000143
# Val Loss: 0.000260
# Learning Rate: 0.000031
#
# Epoch [81/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [81/150]
# Train Loss: 0.000143
# Val Loss: 0.000259
# Learning Rate: 0.000031
#
# Epoch [82/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [82/150]
# Train Loss: 0.000143
# Val Loss: 0.000260
# Learning Rate: 0.000031
#
# Epoch [83/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [83/150]
# Train Loss: 0.000142
# Val Loss: 0.000260
# Learning Rate: 0.000031
#
# Epoch [84/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [84/150]
# Train Loss: 0.000142
# Val Loss: 0.000261
# Learning Rate: 0.000031
#
# Epoch [85/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [85/150]
# Train Loss: 0.000142
# Val Loss: 0.000261
# Learning Rate: 0.000016
#
# Epoch [86/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [86/150]
# Train Loss: 0.000142
# Val Loss: 0.000260
# Learning Rate: 0.000016
#
# Epoch [87/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [87/150]
# Train Loss: 0.000142
# Val Loss: 0.000260
# Learning Rate: 0.000016
#
# Epoch [88/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [88/150]
# Train Loss: 0.000142
# Val Loss: 0.000260
# Learning Rate: 0.000016
#
# Epoch [89/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [89/150]
# Train Loss: 0.000141
# Val Loss: 0.000260
# Learning Rate: 0.000016
#
# Epoch [90/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [90/150]
# Train Loss: 0.000141
# Val Loss: 0.000260
# Learning Rate: 0.000016
#
# Epoch [91/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [91/150]
# Train Loss: 0.000141
# Val Loss: 0.000260
# Learning Rate: 0.000008
#
# Epoch [92/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [92/150]
# Train Loss: 0.000141
# Val Loss: 0.000260
# Learning Rate: 0.000008
#
# Epoch [93/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [93/150]
# Train Loss: 0.000141
# Val Loss: 0.000260
# Learning Rate: 0.000008
#
# Epoch [94/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [94/150]
# Train Loss: 0.000141
# Val Loss: 0.000260
# Learning Rate: 0.000008
#
# Epoch [95/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [95/150]
# Train Loss: 0.000141
# Val Loss: 0.000261
# Learning Rate: 0.000008
#
# Epoch [96/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [96/150]
# Train Loss: 0.000141
# Val Loss: 0.000260
# Learning Rate: 0.000008
#
# Epoch [97/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [97/150]
# Train Loss: 0.000141
# Val Loss: 0.000260
# Learning Rate: 0.000004
#
# Epoch [98/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [98/150]
# Train Loss: 0.000141
# Val Loss: 0.000261
# Learning Rate: 0.000004
#
# Epoch [99/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [99/150]
# Train Loss: 0.000141
# Val Loss: 0.000261
# Learning Rate: 0.000004
#
# Epoch [100/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [100/150]
# Train Loss: 0.000141
# Val Loss: 0.000261
# Learning Rate: 0.000004
#
# Epoch [101/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [101/150]
# Train Loss: 0.000141
# Val Loss: 0.000260
# Learning Rate: 0.000004
#
# Epoch [102/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [102/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000004
#
# Epoch [103/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [103/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000002
#
# Epoch [104/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [104/150]
# Train Loss: 0.000140
# Val Loss: 0.000260
# Learning Rate: 0.000002
#
# Epoch [105/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [105/150]
# Train Loss: 0.000140
# Val Loss: 0.000260
# Learning Rate: 0.000002
#
# Epoch [106/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [106/150]
# Train Loss: 0.000140
# Val Loss: 0.000260
# Learning Rate: 0.000002
#
# Epoch [107/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [107/150]
# Train Loss: 0.000140
# Val Loss: 0.000260
# Learning Rate: 0.000002
#
# Epoch [108/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [108/150]
# Train Loss: 0.000140
# Val Loss: 0.000260
# Learning Rate: 0.000002
#
# Epoch [109/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [109/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000001
#
# Epoch [110/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [110/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000001
#
# Epoch [111/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [111/150]
# Train Loss: 0.000140
# Val Loss: 0.000260
# Learning Rate: 0.000001
#
# Epoch [112/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [112/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000001
#
# Epoch [113/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [113/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000001
#
# Epoch [114/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [114/150]
# Train Loss: 0.000140
# Val Loss: 0.000260
# Learning Rate: 0.000001
#
# Epoch [115/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [115/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [116/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [116/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [117/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [117/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [118/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [118/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [119/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [119/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [120/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [120/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [121/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [121/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [122/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [122/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [123/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [123/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [124/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [124/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [125/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [125/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [126/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [126/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [127/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [127/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [128/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [128/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [129/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [129/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [130/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [130/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [131/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [131/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [132/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [132/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [133/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [133/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [134/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [134/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [135/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [135/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [136/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [136/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [137/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [137/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [138/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [138/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [139/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [139/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [140/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [140/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [141/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [141/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [142/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [142/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [143/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [143/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [144/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [144/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [145/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [145/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [146/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [146/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [147/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [147/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [148/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [148/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [149/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [149/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000
#
# Epoch [150/150]
# Val Batch [70/75], Loss: 0.000059
# Epoch [150/150]
# Train Loss: 0.000140
# Val Loss: 0.000261
# Learning Rate: 0.000000

# %%
def reconstruct_and_compare(model, test_loader, device):
    """Reconstruct full images using 32x32 patches with proper boundary handling"""
    model.eval()
    
    # Get a batch
    batch = next(iter(test_loader))
    
    # Get original image name and load full images
    img_file = batch['image_file'][0]
    
    # Load full input image (Bayer)
    input_path = os.path.join(data['test_dataset'].input_dir, img_file)
    input_img = cv2.imread(input_path, cv2.IMREAD_UNCHANGED)
    bayer_img = input_img.astype(np.float32) / 65535.0
    
    # Load full ground truth image
    gt_path = os.path.join(data['test_dataset'].groundtruth_dir, img_file)
    gt_img = cv2.imread(gt_path)
    gt_img = cv2.cvtColor(gt_img, cv2.COLOR_BGR2RGB)
    gt_img = gt_img.astype(np.float32) / 255.0
    
    # Create bilinear interpolation
    bayer_uint8 = (bayer_img * 255).astype(np.uint8)
    bilinear = cv2.cvtColor(bayer_uint8, cv2.COLOR_BAYER_BG2RGB_EA)
    bilinear = bilinear.astype(np.float32) / 255.0
    
    # Process full image with UNet
    patch_size = 32
    overlap = 8
    h, w = bayer_img.shape
    output_img = np.zeros((h, w, 3), dtype=np.float32)
    count = np.zeros((h, w, 3), dtype=np.float32)
    
    print(f"Processing full image: {img_file}")
    print(f"Image size: {h}x{w}")
    
    with torch.no_grad():
        # Make sure to cover the entire image width
        for i in range(0, h, patch_size - overlap):
            for j in range(0, w, patch_size - overlap):
                # Handle boundary cases
                i_end = min(i + patch_size, h)
                j_end = min(j + patch_size, w)
                i_start = max(0, i_end - patch_size)
                j_start = max(0, j_end - patch_size)
                
                # Extract patch
                patch = bayer_img[i_start:i_end, j_start:j_end]
                
                # Pad if necessary
                if patch.shape[0] < patch_size or patch.shape[1] < patch_size:
                    padded_patch = np.zeros((patch_size, patch_size), dtype=patch.dtype)
                    padded_patch[:patch.shape[0], :patch.shape[1]] = patch
                    patch = padded_patch
                
                # Convert to tensor
                patch_tensor = torch.from_numpy(patch).float().unsqueeze(0).unsqueeze(0)
                patch_tensor = patch_tensor.to(device)
                
                # Process patch
                output_patch = model(patch_tensor)
                output_patch = output_patch.squeeze().cpu().numpy()
                output_patch = np.transpose(output_patch, (1, 2, 0))
                
                # If we padded, only take the valid region
                if i_end - i_start < patch_size or j_end - j_start < patch_size:
                    output_patch = output_patch[:i_end-i_start, :j_end-j_start]
                
                # Add to output image with soft blending
                output_img[i_start:i_end, j_start:j_end] += output_patch
                count[i_start:i_end, j_start:j_end] += 1
    
    # Average overlapping regions
    output_img = np.divide(output_img, count, where=count!=0)
    
    print(f"Reconstruction complete. Output shape: {output_img.shape}")
    print(f"Valid pixels: {np.sum(count > 0)}/{h*w*3}")
    
    def calculate_cpsnr(img1, img2):
        """Calculate color PSNR (average of per-channel PSNR)"""
        assert img1.shape == img2.shape
        psnr_channels = []
        
        for c in range(3):  # For each color channel
            mse = np.mean((img1[..., c] - img2[..., c]) ** 2)
            if mse == 0:
                psnr_channels.append(float('inf'))
            else:
                psnr_channels.append(20 * np.log10(1.0 / np.sqrt(mse)))
        
        return np.mean(psnr_channels), psnr_channels
    
    def calculate_ssim(img1, img2):
        """Simplified SSIM calculation"""
        c1 = (0.01 * 1) ** 2
        c2 = (0.03 * 1) ** 2
        
        img1 = img1.transpose(2, 0, 1)  # Convert to CxHxW
        img2 = img2.transpose(2, 0, 1)
        
        mu1 = img1.mean(axis=(1, 2), keepdims=True)
        mu2 = img2.mean(axis=(1, 2), keepdims=True)
        
        sigma1 = np.std(img1, axis=(1, 2), keepdims=True)
        sigma2 = np.std(img2, axis=(1, 2), keepdims=True)
        sigma12 = np.mean((img1 - mu1) * (img2 - mu2), axis=(1, 2), keepdims=True)
        
        ssim = ((2 * mu1 * mu2 + c1) * (2 * sigma12 + c2)) / \
               ((mu1**2 + mu2**2 + c1) * (sigma1**2 + sigma2**2 + c2))
        
        return ssim.mean()
    
    # Calculate metrics
    bilinear_cpsnr, bilinear_channel_psnr = calculate_cpsnr(gt_img, bilinear)
    network_cpsnr, network_channel_psnr = calculate_cpsnr(gt_img, output_img)
    
    bilinear_ssim = calculate_ssim(gt_img, bilinear)
    network_ssim = calculate_ssim(gt_img, output_img)
    
    # Visualize results
    fig, axes = plt.subplots(2, 2, figsize=(20, 20))
    
    # Bayer pattern
    axes[0, 0].imshow(bayer_img, cmap='gray')
    axes[0, 0].set_title('Bayer Pattern')
    axes[0, 0].axis('off')
    
    # Bilinear demosaicing
    axes[0, 1].imshow(np.clip(bilinear, 0, 1))
    axes[0, 1].set_title(f'Bilinear Demosaicing\ncPSNR: {bilinear_cpsnr:.2f} dB\nSSIM: {bilinear_ssim:.4f}')
    axes[0, 1].axis('off')
    
    # Ground truth
    axes[1, 0].imshow(gt_img)
    axes[1, 0].set_title('Ground Truth')
    axes[1, 0].axis('off')
    
    # Our network output
    axes[1, 1].imshow(np.clip(output_img, 0, 1))
    axes[1, 1].set_title(f'UNet Output\ncPSNR: {network_cpsnr:.2f} dB\nSSIM: {network_ssim:.4f}')
    axes[1, 1].axis('off')
    
    plt.suptitle(f'Demosaicing Results - {img_file}', y=0.95, fontsize=16)
    plt.tight_layout()
    plt.show()
    
    # Print detailed quantitative results
    print("\nQuantitative Results:")
    print("\nBilinear Interpolation:")
    print(f"cPSNR: {bilinear_cpsnr:.2f} dB")
    print(f"Channel PSNRs - R: {bilinear_channel_psnr[0]:.2f}, G: {bilinear_channel_psnr[1]:.2f}, B: {bilinear_channel_psnr[2]:.2f}")
    print(f"SSIM: {bilinear_ssim:.4f}")
    
    print("\nUNet Results:")
    print(f"cPSNR: {network_cpsnr:.2f} dB")
    print(f"Channel PSNRs - R: {network_channel_psnr[0]:.2f}, G: {network_channel_psnr[1]:.2f}, B: {network_channel_psnr[2]:.2f}")
    print(f"SSIM: {network_ssim:.4f}")
    
    print("\nImprovements:")
    print(f"cPSNR Improvement: {network_cpsnr - bilinear_cpsnr:.2f} dB")
    print(f"SSIM Improvement: {network_ssim - bilinear_ssim:.4f}")
    
    return {
        'bilinear_cpsnr': bilinear_cpsnr,
        'network_cpsnr': network_cpsnr,
        'bilinear_channel_psnr': bilinear_channel_psnr,
        'network_channel_psnr': network_channel_psnr,
        'bilinear_ssim': bilinear_ssim,
        'network_ssim': network_ssim
    }

# %%
# Eighth cell - Load Best Model and Evaluate

# Load best model
checkpoint = torch.load('best_unet_model.pth')
model.load_state_dict(checkpoint['model_state_dict'])
print(f"Loaded model from epoch {checkpoint['epoch']} with validation loss {checkpoint['val_loss']:.6f}")

# Test the reconstruction
metrics = reconstruct_and_compare(model, data['test_loader'], device)
# Out:
# Loaded model from epoch 60 with validation loss 0.000258
# /tmp/ipykernel_2039191/3242960249.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('best_unet_model.pth')
# Processing full image: 100.png
# Image size: 132x220
# Reconstruction complete. Output shape: (132, 220, 3)
# Valid pixels: 87120/87120
# Quantitative Results:
#
# Bilinear Interpolation:
# cPSNR: 28.63 dB
# Channel PSNRs - R: 26.59, G: 32.16, B: 27.14
# SSIM: 0.9743
#
# UNet Results:
# cPSNR: 36.83 dB
# Channel PSNRs - R: 35.38, G: 39.85, B: 35.26
# SSIM: 0.9964
#
# Improvements:
# cPSNR Improvement: 8.20 dB
# SSIM Improvement: 0.0221
