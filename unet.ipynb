# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn

# Set matplotlib to display in notebook
# %matplotlib inline


# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.double_conv(x)

class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()
        # Encoder
        self.conv1 = DoubleConv(1, 64)
        self.conv2 = DoubleConv(64, 128)
        self.conv3 = DoubleConv(128, 256)
        self.conv4 = DoubleConv(256, 512)
        self.conv5 = DoubleConv(512, 1024)
        
        # Decoder
        self.up_conv4 = DoubleConv(1024 + 512, 512)
        self.up_conv3 = DoubleConv(512 + 256, 256)
        self.up_conv2 = DoubleConv(256 + 128, 128)
        self.up_conv1 = DoubleConv(128 + 64, 64)
        
        # Final convolution
        self.final_conv = nn.Conv2d(64, 3, kernel_size=1)
        
        # Pooling and upsampling
        self.pool = nn.MaxPool2d(2)
        self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        
    def forward(self, x):
        # Encoder
        conv1 = self.conv1(x)
        x = self.pool(conv1)
        
        conv2 = self.conv2(x)
        x = self.pool(conv2)
        
        conv3 = self.conv3(x)
        x = self.pool(conv3)
        
        conv4 = self.conv4(x)
        x = self.pool(conv4)
        
        # Bridge
        x = self.conv5(x)
        
        # Decoder
        x = self.up(x)
        x = torch.cat([x, conv4], dim=1)
        x = self.up_conv4(x)
        
        x = self.up(x)
        x = torch.cat([x, conv3], dim=1)
        x = self.up_conv3(x)
        
        x = self.up(x)
        x = torch.cat([x, conv2], dim=1)
        x = self.up_conv2(x)
        
        x = self.up(x)
        x = torch.cat([x, conv1], dim=1)
        x = self.up_conv1(x)
        
        # Final convolution
        x = self.final_conv(x)
        return x

# Initialize model
model = UNet().to(device)
print("Model initialized")
# Out:
# Model initialized

# %%
class DemosaicingDataset(Dataset):
    def __init__(self, root_dir, split_file, patch_size=128, stride=128, transform=None):
        """Initialize Demosaicing dataset"""
        self.root_dir = root_dir
        self.groundtruth_dir = os.path.join(root_dir, 'groundtruth')
        self.input_dir = os.path.join(root_dir, 'input')
        self.patch_size = patch_size  # Increased patch size for UNet
        self.stride = stride
        self.transform = transform
        
        # Read image list from split file
        with open(split_file, 'r') as f:
            self.image_files = [line.strip() + '.png' for line in f.readlines()]
            
        print(f"Found {len(self.image_files)} images in {os.path.basename(split_file)}")
        
        # Pre-compute patches
        self.patches = self._prepare_patches()
        
    def _prepare_patches(self):
        """Prepare patches from all images"""
        patches = []
        
        for i, img_file in enumerate(self.image_files):
            print(f"Processing image {i+1}/{len(self.image_files)}", end='\r')
            
            # Load ground truth image
            gt_path = os.path.join(self.groundtruth_dir, img_file)
            gt_img = cv2.imread(gt_path)
            gt_img = cv2.cvtColor(gt_img, cv2.COLOR_BGR2RGB)
            
            # Load input image (raw Bayer)
            input_path = os.path.join(self.input_dir, img_file)
            input_img = cv2.imread(input_path, cv2.IMREAD_UNCHANGED)
            
            # Normalize input to [0, 1]
            input_img = input_img.astype(np.float32) / 65535.0
            gt_img = gt_img.astype(np.float32) / 255.0
            
            # Extract patches
            h, w = input_img.shape
            for i in range(0, h - self.patch_size + 1, self.stride):
                for j in range(0, w - self.patch_size + 1, self.stride):
                    input_patch = input_img[i:i+self.patch_size, j:j+self.patch_size]
                    gt_patch = gt_img[i:i+self.patch_size, j:j+self.patch_size]
                    
                    # Skip patches with low variance
                    if input_patch.std() > 0.02:
                        patches.append({
                            'input': input_patch,
                            'target': gt_patch,
                            'image_file': img_file,
                            'position': (i, j)
                        })
        
        print(f"\nExtracted {len(patches)} valid patches")
        return patches
    
    def __len__(self):
        return len(self.patches)
    
    def __getitem__(self, idx):
        patch = self.patches[idx]
        
        # Convert to torch tensors
        input_tensor = torch.from_numpy(patch['input']).float().unsqueeze(0)
        target_tensor = torch.from_numpy(patch['target']).float().permute(2, 0, 1)
        
        if self.transform:
            input_tensor = self.transform(input_tensor)
            target_tensor = self.transform(target_tensor)
            
        return {
            'input': input_tensor,
            'target': target_tensor,
            'image_file': patch['image_file'],
            'position': patch['position']
        }

# %%
def prepare_demosaicing_datasets(dataset_path, batch_size=16, num_workers=4):
    """Prepare training, validation and test datasets and dataloaders"""
    split_files = {
        'train': os.path.join(dataset_path, 'train.txt'),
        'val': os.path.join(dataset_path, 'validation.txt'),
        'test': os.path.join(dataset_path, 'test.txt')
    }
    
    datasets = {}
    dataloaders = {}
    
    for split_name, split_file in split_files.items():
        if os.path.exists(split_file):
            print(f"\nPreparing {split_name} dataset...")
            
            # Create dataset
            datasets[f'{split_name}_dataset'] = DemosaicingDataset(
                root_dir=dataset_path,
                split_file=split_file,
                patch_size=128,  # Larger patches for UNet
                stride=128
            )
            
            # Create dataloader
            dataloaders[f'{split_name}_loader'] = DataLoader(
                datasets[f'{split_name}_dataset'],
                batch_size=batch_size,
                shuffle=(split_name == 'train'),
                num_workers=num_workers,
                pin_memory=True
            )
        else:
            print(f"Warning: {split_file} not found. Skipping {split_name} split.")
    
    return {**datasets, **dataloaders}

# Prepare datasets
dataset_path = 'dataset/MSR-Demosaicing/MSR-Demosaicing/Dataset_LINEAR_without_noise/bayer_panasonic'
data = prepare_demosaicing_datasets(dataset_path=dataset_path, batch_size=16, num_workers=4)

# Print statistics
print("\nDataset Statistics:")
print("-" * 50)
for split in ['train', 'val', 'test']:
    if f'{split}_dataset' in data:
        print(f"{split.capitalize()} samples: {len(data[f'{split}_dataset'])}")
# Out:
# Preparing train dataset...
# Found 200 images in train.txt
# Processing image 200/200
# Extracted 199 valid patches
#
# Preparing val dataset...
# Found 100 images in validation.txt
# Processing image 100/100
# Extracted 100 valid patches
#
# Preparing test dataset...
# Found 200 images in test.txt
# Processing image 200/200
# Extracted 200 valid patches
#
# Dataset Statistics:
# --------------------------------------------------
# Train samples: 199
# Val samples: 100
# Test samples: 200

# %%
def train_epoch(model, train_loader, criterion, optimizer, device):
    """Train for one epoch"""
    model.train()
    running_loss = 0.0
    
    for i, batch in enumerate(train_loader):
        inputs = batch['input'].to(device)
        targets = batch['target'].to(device)
        
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * inputs.size(0)
        
        if (i + 1) % 10 == 0:
            print(f'Batch [{i+1}/{len(train_loader)}], Loss: {loss.item():.6f}', end='\r')
    
    return running_loss / len(train_loader.dataset)

def validate(model, val_loader, criterion, device):
    """Validate the model"""
    model.eval()
    running_loss = 0.0
    
    with torch.no_grad():
        for i, batch in enumerate(val_loader):
            inputs = batch['input'].to(device)
            targets = batch['target'].to(device)
            
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            
            running_loss += loss.item() * inputs.size(0)
            
            if (i + 1) % 10 == 0:
                print(f'Val Batch [{i+1}/{len(val_loader)}], Loss: {loss.item():.6f}', end='\r')
    
    return running_loss / len(val_loader.dataset)

# %%
# Training setup
criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.5)

# Training parameters
n_epochs = 100
best_val_loss = float('inf')
train_losses = []
val_losses = []

# Training loop
print("Starting training...")
for epoch in range(n_epochs):
    print(f'\nEpoch [{epoch+1}/{n_epochs}]')
    
    # Train
    train_loss = train_epoch(model, data['train_loader'], criterion, optimizer, device)
    train_losses.append(train_loss)
    
    # Validate
    val_loss = validate(model, data['val_loader'], criterion, device)
    val_losses.append(val_loss)
    
    # Scheduler step
    scheduler.step(val_loss)
    
    # Save best model
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'train_loss': train_loss,
            'val_loss': val_loss,
        }, 'best_unet_model.pth')
    
    # Print epoch results
    print(f'\nEpoch [{epoch+1}/{n_epochs}]')
    print(f'Train Loss: {train_loss:.6f}')
    print(f'Val Loss: {val_loss:.6f}')
    print(f'Learning Rate: {optimizer.param_groups[0]["lr"]:.6f}')

# Plot training results
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Losses')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Starting training...
#
# Epoch [1/100]
# Batch [10/13], Loss: 0.090711
# Epoch [1/100]
# Train Loss: 107.395564
# Val Loss: 0.055678
# Learning Rate: 0.001000
#
# Epoch [2/100]
# Batch [10/13], Loss: 0.094780
# Epoch [2/100]
# Train Loss: 0.077533
# Val Loss: 0.088448
# Learning Rate: 0.001000
#
# Epoch [3/100]
# Batch [10/13], Loss: 0.070024
# Epoch [3/100]
# Train Loss: 0.074236
# Val Loss: 0.072805
# Learning Rate: 0.001000
#
# Epoch [4/100]
# Batch [10/13], Loss: 0.036261
# Epoch [4/100]
# Train Loss: 0.048118
# Val Loss: 0.022283
# Learning Rate: 0.001000
#
# Epoch [5/100]
# Batch [10/13], Loss: 0.007631
# Epoch [5/100]
# Train Loss: 0.012150
# Val Loss: 0.009503
# Learning Rate: 0.001000
#
# Epoch [6/100]
# Batch [10/13], Loss: 0.007196
# Epoch [6/100]
# Train Loss: 0.007552
# Val Loss: 0.007261
# Learning Rate: 0.001000
#
# Epoch [7/100]
# Batch [10/13], Loss: 0.005238
# Epoch [7/100]
# Train Loss: 0.005892
# Val Loss: 0.005928
# Learning Rate: 0.001000
#
# Epoch [8/100]
# Batch [10/13], Loss: 0.004220
# Epoch [8/100]
# Train Loss: 0.005010
# Val Loss: 0.005431
# Learning Rate: 0.001000
#
# Epoch [9/100]
# Batch [10/13], Loss: 0.005007
# Epoch [9/100]
# Train Loss: 0.004564
# Val Loss: 0.005069
# Learning Rate: 0.001000
#
# Epoch [10/100]
# Batch [10/13], Loss: 0.003518
# Epoch [10/100]
# Train Loss: 0.004229
# Val Loss: 0.004637
# Learning Rate: 0.001000
#
# Epoch [11/100]
# Batch [10/13], Loss: 0.003449
# Epoch [11/100]
# Train Loss: 0.003823
# Val Loss: 0.004371
# Learning Rate: 0.001000
#
# Epoch [12/100]
# Batch [10/13], Loss: 0.002753
# Epoch [12/100]
# Train Loss: 0.003591
# Val Loss: 0.004163
# Learning Rate: 0.001000
#
# Epoch [13/100]
# Batch [10/13], Loss: 0.002958
# Epoch [13/100]
# Train Loss: 0.003486
# Val Loss: 0.004394
# Learning Rate: 0.001000
#
# Epoch [14/100]
# Batch [10/13], Loss: 0.003564
# Epoch [14/100]
# Train Loss: 0.003492
# Val Loss: 0.004104
# Learning Rate: 0.001000
#
# Epoch [15/100]
# Batch [10/13], Loss: 0.003021
# Epoch [15/100]
# Train Loss: 0.003228
# Val Loss: 0.003769
# Learning Rate: 0.001000
#
# Epoch [16/100]
# Batch [10/13], Loss: 0.003747
# Epoch [16/100]
# Train Loss: 0.003012
# Val Loss: 0.003746
# Learning Rate: 0.001000
#
# Epoch [17/100]
# Batch [10/13], Loss: 0.001874
# Epoch [17/100]
# Train Loss: 0.002909
# Val Loss: 0.003573
# Learning Rate: 0.001000
#
# Epoch [18/100]
# Batch [10/13], Loss: 0.002907
# Epoch [18/100]
# Train Loss: 0.002736
# Val Loss: 0.003323
# Learning Rate: 0.001000
#
# Epoch [19/100]
# Batch [10/13], Loss: 0.002691
# Epoch [19/100]
# Train Loss: 0.002571
# Val Loss: 0.003255
# Learning Rate: 0.001000
#
# Epoch [20/100]
# Batch [10/13], Loss: 0.002939
# Epoch [20/100]
# Train Loss: 0.002539
# Val Loss: 0.003215
# Learning Rate: 0.001000
#
# Epoch [21/100]
# Batch [10/13], Loss: 0.002165
# Epoch [21/100]
# Train Loss: 0.002386
# Val Loss: 0.003169
# Learning Rate: 0.001000
#
# Epoch [22/100]
# Batch [10/13], Loss: 0.002469
# Epoch [22/100]
# Train Loss: 0.002324
# Val Loss: 0.002980
# Learning Rate: 0.001000
#
# Epoch [23/100]
# Batch [10/13], Loss: 0.002120
# Epoch [23/100]
# Train Loss: 0.002210
# Val Loss: 0.002879
# Learning Rate: 0.001000
#
# Epoch [24/100]
# Batch [10/13], Loss: 0.001745
# Epoch [24/100]
# Train Loss: 0.002172
# Val Loss: 0.002793
# Learning Rate: 0.001000
#
# Epoch [25/100]
# Batch [10/13], Loss: 0.001587
# Epoch [25/100]
# Train Loss: 0.002094
# Val Loss: 0.002679
# Learning Rate: 0.001000
#
# Epoch [26/100]
# Batch [10/13], Loss: 0.001463
# Epoch [26/100]
# Train Loss: 0.002048
# Val Loss: 0.002819
# Learning Rate: 0.001000
#
# Epoch [27/100]
# Batch [10/13], Loss: 0.002192
# Epoch [27/100]
# Train Loss: 0.002056
# Val Loss: 0.002690
# Learning Rate: 0.001000
#
# Epoch [28/100]
# Batch [10/13], Loss: 0.001724
# Epoch [28/100]
# Train Loss: 0.002006
# Val Loss: 0.002570
# Learning Rate: 0.001000
#
# Epoch [29/100]
# Batch [10/13], Loss: 0.001536
# Epoch [29/100]
# Train Loss: 0.001953
# Val Loss: 0.002576
# Learning Rate: 0.001000
#
# Epoch [30/100]
# Batch [10/13], Loss: 0.001489
# Epoch [30/100]
# Train Loss: 0.001925
# Val Loss: 0.002592
# Learning Rate: 0.001000
#
# Epoch [31/100]
# Batch [10/13], Loss: 0.001595
# Epoch [31/100]
# Train Loss: 0.001847
# Val Loss: 0.002587
# Learning Rate: 0.001000
#
# Epoch [32/100]
# Batch [10/13], Loss: 0.001856
# Epoch [32/100]
# Train Loss: 0.001860
# Val Loss: 0.002363
# Learning Rate: 0.001000
#
# Epoch [33/100]
# Batch [10/13], Loss: 0.001325
# Epoch [33/100]
# Train Loss: 0.001768
# Val Loss: 0.002347
# Learning Rate: 0.001000
#
# Epoch [34/100]
# Batch [10/13], Loss: 0.001587
# Epoch [34/100]
# Train Loss: 0.001879
# Val Loss: 0.002538
# Learning Rate: 0.001000
#
# Epoch [35/100]
# Batch [10/13], Loss: 0.001870
# Epoch [35/100]
# Train Loss: 0.001852
# Val Loss: 0.002489
# Learning Rate: 0.001000
#
# Epoch [36/100]
# Batch [10/13], Loss: 0.001665
# Epoch [36/100]
# Train Loss: 0.001798
# Val Loss: 0.002256
# Learning Rate: 0.001000
#
# Epoch [37/100]
# Batch [10/13], Loss: 0.001872
# Epoch [37/100]
# Train Loss: 0.001786
# Val Loss: 0.002436
# Learning Rate: 0.001000
#
# Epoch [38/100]
# Batch [10/13], Loss: 0.001937
# Epoch [38/100]
# Train Loss: 0.001745
# Val Loss: 0.002412
# Learning Rate: 0.001000
#
# Epoch [39/100]
# Batch [10/13], Loss: 0.001982
# Epoch [39/100]
# Train Loss: 0.001697
# Val Loss: 0.002034
# Learning Rate: 0.001000
#
# Epoch [40/100]
# Batch [10/13], Loss: 0.001189
# Epoch [40/100]
# Train Loss: 0.001607
# Val Loss: 0.001927
# Learning Rate: 0.001000
#
# Epoch [41/100]
# Batch [10/13], Loss: 0.002260
# Epoch [41/100]
# Train Loss: 0.001564
# Val Loss: 0.002202
# Learning Rate: 0.001000
#
# Epoch [42/100]
# Batch [10/13], Loss: 0.001592
# Epoch [42/100]
# Train Loss: 0.001614
# Val Loss: 0.002380
# Learning Rate: 0.001000
#
# Epoch [43/100]
# Batch [10/13], Loss: 0.001579
# Epoch [43/100]
# Train Loss: 0.001564
# Val Loss: 0.002106
# Learning Rate: 0.001000
#
# Epoch [44/100]
# Batch [10/13], Loss: 0.001599
# Epoch [44/100]
# Train Loss: 0.001559
# Val Loss: 0.001870
# Learning Rate: 0.001000
#
# Epoch [45/100]
# Batch [10/13], Loss: 0.001931
# Epoch [45/100]
# Train Loss: 0.001456
# Val Loss: 0.001820
# Learning Rate: 0.001000
#
# Epoch [46/100]
# Batch [10/13], Loss: 0.002021
# Epoch [46/100]
# Train Loss: 0.001509
# Val Loss: 0.002185
# Learning Rate: 0.001000
#
# Epoch [47/100]
# Batch [10/13], Loss: 0.001373
# Epoch [47/100]
# Train Loss: 0.001661
# Val Loss: 0.001783
# Learning Rate: 0.001000
#
# Epoch [48/100]
# Batch [10/13], Loss: 0.001117
# Epoch [48/100]
# Train Loss: 0.001442
# Val Loss: 0.001765
# Learning Rate: 0.001000
#
# Epoch [49/100]
# Batch [10/13], Loss: 0.001699
# Epoch [49/100]
# Train Loss: 0.001352
# Val Loss: 0.001889
# Learning Rate: 0.001000
#
# Epoch [50/100]
# Batch [10/13], Loss: 0.001334
# Epoch [50/100]
# Train Loss: 0.001481
# Val Loss: 0.001713
# Learning Rate: 0.001000
#
# Epoch [51/100]
# Batch [10/13], Loss: 0.001350
# Epoch [51/100]
# Train Loss: 0.001354
# Val Loss: 0.002020
# Learning Rate: 0.001000
#
# Epoch [52/100]
# Batch [10/13], Loss: 0.001350
# Epoch [52/100]
# Train Loss: 0.001532
# Val Loss: 0.001673
# Learning Rate: 0.001000
#
# Epoch [53/100]
# Batch [10/13], Loss: 0.001267
# Epoch [53/100]
# Train Loss: 0.001414
# Val Loss: 0.001596
# Learning Rate: 0.001000
#
# Epoch [54/100]
# Batch [10/13], Loss: 0.001203
# Epoch [54/100]
# Train Loss: 0.001294
# Val Loss: 0.001442
# Learning Rate: 0.001000
#
# Epoch [55/100]
# Batch [10/13], Loss: 0.001051
# Epoch [55/100]
# Train Loss: 0.001287
# Val Loss: 0.001435
# Learning Rate: 0.001000
#
# Epoch [56/100]
# Batch [10/13], Loss: 0.001260
# Epoch [56/100]
# Train Loss: 0.001180
# Val Loss: 0.001461
# Learning Rate: 0.001000
#
# Epoch [57/100]
# Batch [10/13], Loss: 0.001929
# Epoch [57/100]
# Train Loss: 0.001178
# Val Loss: 0.001331
# Learning Rate: 0.001000
#
# Epoch [58/100]
# Batch [10/13], Loss: 0.001780
# Epoch [58/100]
# Train Loss: 0.001155
# Val Loss: 0.001794
# Learning Rate: 0.001000
#
# Epoch [59/100]
# Batch [10/13], Loss: 0.001328
# Epoch [59/100]
# Train Loss: 0.001316
# Val Loss: 0.001459
# Learning Rate: 0.001000
#
# Epoch [60/100]
# Batch [10/13], Loss: 0.001175
# Epoch [60/100]
# Train Loss: 0.001237
# Val Loss: 0.001330
# Learning Rate: 0.001000
#
# Epoch [61/100]
# Batch [10/13], Loss: 0.001418
# Epoch [61/100]
# Train Loss: 0.001406
# Val Loss: 0.002436
# Learning Rate: 0.001000
#
# Epoch [62/100]
# Batch [10/13], Loss: 0.001312
# Epoch [62/100]
# Train Loss: 0.001362
# Val Loss: 0.001697
# Learning Rate: 0.001000
#
# Epoch [63/100]
# Batch [10/13], Loss: 0.001597
# Epoch [63/100]
# Train Loss: 0.001214
# Val Loss: 0.001608
# Learning Rate: 0.001000
#
# Epoch [64/100]
# Batch [10/13], Loss: 0.000856
# Epoch [64/100]
# Train Loss: 0.001168
# Val Loss: 0.001915
# Learning Rate: 0.001000
#
# Epoch [65/100]
# Batch [10/13], Loss: 0.001015
# Epoch [65/100]
# Train Loss: 0.001315
# Val Loss: 0.001606
# Learning Rate: 0.001000
#
# Epoch [66/100]
# Batch [10/13], Loss: 0.001445
# Epoch [66/100]
# Train Loss: 0.001458
# Val Loss: 0.002255
# Learning Rate: 0.000500
#
# Epoch [67/100]
# Batch [10/13], Loss: 0.002283
# Epoch [67/100]
# Train Loss: 0.001382
# Val Loss: 0.001479
# Learning Rate: 0.000500
#
# Epoch [68/100]
# Batch [10/13], Loss: 0.001638
# Epoch [68/100]
# Train Loss: 0.001175
# Val Loss: 0.001434
# Learning Rate: 0.000500
#
# Epoch [69/100]
# Batch [10/13], Loss: 0.000810
# Epoch [69/100]
# Train Loss: 0.001106
# Val Loss: 0.001272
# Learning Rate: 0.000500
#
# Epoch [70/100]
# Batch [10/13], Loss: 0.001019
# Epoch [70/100]
# Train Loss: 0.001011
# Val Loss: 0.001118
# Learning Rate: 0.000500
#
# Epoch [71/100]
# Batch [10/13], Loss: 0.001167
# Epoch [71/100]
# Train Loss: 0.001187
# Val Loss: 0.001337
# Learning Rate: 0.000500
#
# Epoch [72/100]
# Batch [10/13], Loss: 0.001020
# Epoch [72/100]
# Train Loss: 0.000959
# Val Loss: 0.001137
# Learning Rate: 0.000500
#
# Epoch [73/100]
# Batch [10/13], Loss: 0.001135
# Epoch [73/100]
# Train Loss: 0.000900
# Val Loss: 0.001075
# Learning Rate: 0.000500
#
# Epoch [74/100]
# Batch [10/13], Loss: 0.000878
# Epoch [74/100]
# Train Loss: 0.000862
# Val Loss: 0.000990
# Learning Rate: 0.000500
#
# Epoch [75/100]
# Batch [10/13], Loss: 0.000632
# Epoch [75/100]
# Train Loss: 0.000832
# Val Loss: 0.001038
# Learning Rate: 0.000500
#
# Epoch [76/100]
# Batch [10/13], Loss: 0.000722
# Epoch [76/100]
# Train Loss: 0.000855
# Val Loss: 0.000944
# Learning Rate: 0.000500
#
# Epoch [77/100]
# Batch [10/13], Loss: 0.000745
# Epoch [77/100]
# Train Loss: 0.000801
# Val Loss: 0.000950
# Learning Rate: 0.000500
#
# Epoch [78/100]
# Batch [10/13], Loss: 0.000585
# Epoch [78/100]
# Train Loss: 0.000787
# Val Loss: 0.000934
# Learning Rate: 0.000500
#
# Epoch [79/100]
# Batch [10/13], Loss: 0.000674
# Epoch [79/100]
# Train Loss: 0.000766
# Val Loss: 0.000906
# Learning Rate: 0.000500
#
# Epoch [80/100]
# Batch [10/13], Loss: 0.000576
# Epoch [80/100]
# Train Loss: 0.000785
# Val Loss: 0.000890
# Learning Rate: 0.000500
#
# Epoch [81/100]
# Batch [10/13], Loss: 0.000964
# Epoch [81/100]
# Train Loss: 0.000761
# Val Loss: 0.000942
# Learning Rate: 0.000500
#
# Epoch [82/100]
# Batch [10/13], Loss: 0.000793
# Epoch [82/100]
# Train Loss: 0.000769
# Val Loss: 0.000937
# Learning Rate: 0.000500
#
# Epoch [83/100]
# Batch [10/13], Loss: 0.000676
# Epoch [83/100]
# Train Loss: 0.000740
# Val Loss: 0.000870
# Learning Rate: 0.000500
#
# Epoch [84/100]
# Batch [10/13], Loss: 0.000887
# Epoch [84/100]
# Train Loss: 0.000726
# Val Loss: 0.000926
# Learning Rate: 0.000500
#
# Epoch [85/100]
# Batch [10/13], Loss: 0.000369
# Epoch [85/100]
# Train Loss: 0.000739
# Val Loss: 0.000864
# Learning Rate: 0.000500
#
# Epoch [86/100]
# Batch [10/13], Loss: 0.000820
# Epoch [86/100]
# Train Loss: 0.000708
# Val Loss: 0.000950
# Learning Rate: 0.000500
#
# Epoch [87/100]
# Batch [10/13], Loss: 0.000429
# Epoch [87/100]
# Train Loss: 0.000700
# Val Loss: 0.000914
# Learning Rate: 0.000500
#
# Epoch [88/100]
# Batch [10/13], Loss: 0.000804
# Epoch [88/100]
# Train Loss: 0.000699
# Val Loss: 0.000951
# Learning Rate: 0.000500
#
# Epoch [89/100]
# Batch [10/13], Loss: 0.000647
# Epoch [89/100]
# Train Loss: 0.000763
# Val Loss: 0.000893
# Learning Rate: 0.000500
#
# Epoch [90/100]
# Batch [10/13], Loss: 0.000542
# Epoch [90/100]
# Train Loss: 0.000711
# Val Loss: 0.000862
# Learning Rate: 0.000500
#
# Epoch [91/100]
# Batch [10/13], Loss: 0.000574
# Epoch [91/100]
# Train Loss: 0.000679
# Val Loss: 0.000896
# Learning Rate: 0.000500
#
# Epoch [92/100]
# Batch [10/13], Loss: 0.000450
# Epoch [92/100]
# Train Loss: 0.000695
# Val Loss: 0.000894
# Learning Rate: 0.000500
#
# Epoch [93/100]
# Batch [10/13], Loss: 0.000614
# Epoch [93/100]
# Train Loss: 0.000672
# Val Loss: 0.000865
# Learning Rate: 0.000500
#
# Epoch [94/100]
# Batch [10/13], Loss: 0.000576
# Epoch [94/100]
# Train Loss: 0.000654
# Val Loss: 0.000876
# Learning Rate: 0.000500
#
# Epoch [95/100]
# Batch [10/13], Loss: 0.000566
# Epoch [95/100]
# Train Loss: 0.000633
# Val Loss: 0.000833
# Learning Rate: 0.000500
#
# Epoch [96/100]
# Batch [10/13], Loss: 0.000618
# Epoch [96/100]
# Train Loss: 0.000633
# Val Loss: 0.000847
# Learning Rate: 0.000500
#
# Epoch [97/100]
# Batch [10/13], Loss: 0.000734
# Epoch [97/100]
# Train Loss: 0.000659
# Val Loss: 0.000861
# Learning Rate: 0.000500
#
# Epoch [98/100]
# Batch [10/13], Loss: 0.000428
# Epoch [98/100]
# Train Loss: 0.000641
# Val Loss: 0.000828
# Learning Rate: 0.000500
#
# Epoch [99/100]
# Batch [10/13], Loss: 0.000687
# Epoch [99/100]
# Train Loss: 0.000622
# Val Loss: 0.001006
# Learning Rate: 0.000500
#
# Epoch [100/100]
# Batch [10/13], Loss: 0.000418
# Epoch [100/100]
# Train Loss: 0.000629
# Val Loss: 0.000873
# Learning Rate: 0.000500

# %%
def reconstruct_and_compare(model, test_loader, device):
    """Reconstruct full images and compare different demosaicing methods"""
    model.eval()
    
    # Get a batch
    batch = next(iter(test_loader))
    
    # Get original image name and load full images
    img_file = batch['image_file'][0]
    
    # Load full input image (Bayer)
    input_path = os.path.join(data['test_dataset'].input_dir, img_file)
    input_img = cv2.imread(input_path, cv2.IMREAD_UNCHANGED)
    bayer_img = input_img.astype(np.float32) / 65535.0
    
    # Load full ground truth image
    gt_path = os.path.join(data['test_dataset'].groundtruth_dir, img_file)
    gt_img = cv2.imread(gt_path)
    gt_img = cv2.cvtColor(gt_img, cv2.COLOR_BGR2RGB)
    gt_img = gt_img.astype(np.float32) / 255.0
    
    # Create bilinear interpolation
    bayer_uint8 = (bayer_img * 255).astype(np.uint8)
    bilinear = cv2.cvtColor(bayer_uint8, cv2.COLOR_BAYER_BG2RGB_EA)
    bilinear = bilinear.astype(np.float32) / 255.0
    
    # Process full image with UNet
    patch_size = 128  # Use same patch size as training
    overlap = 16  # Use overlap to avoid boundary artifacts
    h, w = bayer_img.shape
    output_img = np.zeros((h, w, 3), dtype=np.float32)
    count = np.zeros((h, w, 3), dtype=np.float32)
    
    print(f"Processing full image: {img_file}")
    with torch.no_grad():
        for i in range(0, h - patch_size + 1, patch_size - overlap):
            for j in range(0, w - patch_size + 1, patch_size - overlap):
                # Extract patch
                patch = bayer_img[i:i+patch_size, j:j+patch_size]
                
                # Convert to tensor
                patch_tensor = torch.from_numpy(patch).float().unsqueeze(0).unsqueeze(0)
                patch_tensor = patch_tensor.to(device)
                
                # Process patch
                output_patch = model(patch_tensor)
                output_patch = output_patch.squeeze().cpu().numpy()
                output_patch = np.transpose(output_patch, (1, 2, 0))
                
                # Add to output image with soft blending
                output_img[i:i+patch_size, j:j+patch_size] += output_patch
                count[i:i+patch_size, j:j+patch_size] += 1
    
    # Average overlapping regions
    output_img = np.divide(output_img, count, where=count!=0)
    
    def calculate_cpsnr(img1, img2):
        """Calculate color PSNR (average of per-channel PSNR)"""
        assert img1.shape == img2.shape
        psnr_channels = []
        
        for c in range(3):  # For each color channel
            mse = np.mean((img1[..., c] - img2[..., c]) ** 2)
            if mse == 0:
                psnr_channels.append(float('inf'))
            else:
                psnr_channels.append(20 * np.log10(1.0 / np.sqrt(mse)))
        
        # Average PSNR across channels
        return np.mean(psnr_channels), psnr_channels
    
    def calculate_ssim(img1, img2):
        """Simplified SSIM calculation"""
        c1 = (0.01 * 1) ** 2
        c2 = (0.03 * 1) ** 2
        
        img1 = img1.transpose(2, 0, 1)  # Convert to CxHxW
        img2 = img2.transpose(2, 0, 1)
        
        mu1 = img1.mean(axis=(1, 2), keepdims=True)
        mu2 = img2.mean(axis=(1, 2), keepdims=True)
        
        sigma1 = np.std(img1, axis=(1, 2), keepdims=True)
        sigma2 = np.std(img2, axis=(1, 2), keepdims=True)
        sigma12 = np.mean((img1 - mu1) * (img2 - mu2), axis=(1, 2), keepdims=True)
        
        ssim = ((2 * mu1 * mu2 + c1) * (2 * sigma12 + c2)) / \
               ((mu1**2 + mu2**2 + c1) * (sigma1**2 + sigma2**2 + c2))
        
        return ssim.mean()
    
    # Calculate metrics
    bilinear_cpsnr, bilinear_channel_psnr = calculate_cpsnr(gt_img, bilinear)
    network_cpsnr, network_channel_psnr = calculate_cpsnr(gt_img, output_img)
    
    bilinear_ssim = calculate_ssim(gt_img, bilinear)
    network_ssim = calculate_ssim(gt_img, output_img)
    
    # Visualize results
    fig, axes = plt.subplots(2, 2, figsize=(20, 20))
    
    # Bayer pattern
    axes[0, 0].imshow(bayer_img, cmap='gray')
    axes[0, 0].set_title('Bayer Pattern')
    axes[0, 0].axis('off')
    
    # Bilinear demosaicing
    axes[0, 1].imshow(np.clip(bilinear, 0, 1))
    axes[0, 1].set_title(f'Bilinear Demosaicing\ncPSNR: {bilinear_cpsnr:.2f} dB\nSSIM: {bilinear_ssim:.4f}')
    axes[0, 1].axis('off')
    
    # Ground truth
    axes[1, 0].imshow(gt_img)
    axes[1, 0].set_title('Ground Truth')
    axes[1, 0].axis('off')
    
    # Our network output
    axes[1, 1].imshow(np.clip(output_img, 0, 1))
    axes[1, 1].set_title(f'UNet Output\ncPSNR: {network_cpsnr:.2f} dB\nSSIM: {network_ssim:.4f}')
    axes[1, 1].axis('off')
    
    plt.suptitle(f'Demosaicing Results - {img_file}', y=0.95, fontsize=16)
    plt.tight_layout()
    plt.show()
    
    # Print detailed quantitative results
    print("\nQuantitative Results:")
    print("\nBilinear Interpolation:")
    print(f"cPSNR: {bilinear_cpsnr:.2f} dB")
    print(f"Channel PSNRs - R: {bilinear_channel_psnr[0]:.2f}, G: {bilinear_channel_psnr[1]:.2f}, B: {bilinear_channel_psnr[2]:.2f}")
    print(f"SSIM: {bilinear_ssim:.4f}")
    
    print("\nUNet Results:")
    print(f"cPSNR: {network_cpsnr:.2f} dB")
    print(f"Channel PSNRs - R: {network_channel_psnr[0]:.2f}, G: {network_channel_psnr[1]:.2f}, B: {network_channel_psnr[2]:.2f}")
    print(f"SSIM: {network_ssim:.4f}")
    
    print("\nImprovements:")
    print(f"cPSNR Improvement: {network_cpsnr - bilinear_cpsnr:.2f} dB")
    print(f"SSIM Improvement: {network_ssim - bilinear_ssim:.4f}")
    
    # Return metrics for further analysis if needed
    return {
        'bilinear_cpsnr': bilinear_cpsnr,
        'network_cpsnr': network_cpsnr,
        'bilinear_channel_psnr': bilinear_channel_psnr,
        'network_channel_psnr': network_channel_psnr,
        'bilinear_ssim': bilinear_ssim,
        'network_ssim': network_ssim
    }

# Load best model and visualize results
checkpoint = torch.load('best_unet_model.pth')
model.load_state_dict(checkpoint['model_state_dict'])
print(f"Loaded model from epoch {checkpoint['epoch']} with validation loss {checkpoint['val_loss']:.6f}")

# Test the reconstruction
metrics = reconstruct_and_compare(model, data['test_loader'], device)
# Out:
# Loaded model from epoch 97 with validation loss 0.000828
# /tmp/ipykernel_2006747/575254726.py:153: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('best_unet_model.pth')
# Processing full image: 100.png
# Quantitative Results:
#
# Bilinear Interpolation:
# cPSNR: 28.63 dB
# Channel PSNRs - R: 26.59, G: 32.16, B: 27.14
# SSIM: 0.9743
#
# UNet Results:
# cPSNR: 17.63 dB
# Channel PSNRs - R: 18.35, G: 17.72, B: 16.82
# SSIM: 0.7686
#
# Improvements:
# cPSNR Improvement: -11.00 dB
# SSIM Improvement: -0.2057
